# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
# !python inference_image.py --checkpoint ../checkpoints/model_state.pt --images_path test.png
# Out:
# /home/shahid/anaconda3/envs/multimodal126/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1766023942.784944 3929381 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1766023942.850135 3929569 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 580.95.05), renderer: NVIDIA RTX PRO 6000 Blackwell Max-Q Workstation Edition/PCIe/SSE2
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1766023942.907132 3929566 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Paths
input_img_path = "test.png"
output_img_path = "temp/overlays/._0_overlay.jpg"  # change if needed

# Load images
input_img = mpimg.imread(input_img_path)
output_img = mpimg.imread(output_img_path)

# Plot
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].imshow(input_img)
axes[0].set_title("Input Image")
axes[0].axis("off")

axes[1].imshow(output_img)
axes[1].set_title("Output Image")
axes[1].axis("off")

plt.tight_layout()
plt.show()
